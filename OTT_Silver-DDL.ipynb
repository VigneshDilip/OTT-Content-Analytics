# %%
# %sql
use catalog ott_catalog;
DESCRIBE EXTENDED silver.ott_cast;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.silver.ott_cast
USING DELTA
LOCATION 'abfss://silver@storageottanalytics.dfs.core.windows.net/ott_cast'

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.silver.ott_category
USING DELTA
LOCATION 'abfss://silver@storageottanalytics.dfs.core.windows.net/ott_category'

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.silver.ott_countries
USING DELTA
LOCATION 'abfss://silver@storageottanalytics.dfs.core.windows.net/ott_countries'

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.silver.ott_directors
USING DELTA
LOCATION 'abfss://silver@storageottanalytics.dfs.core.windows.net/ott_directors'

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.silver.ott_titles
USING DELTA
LOCATION 'abfss://silver@storageottanalytics.dfs.core.windows.net/ott_titles'
