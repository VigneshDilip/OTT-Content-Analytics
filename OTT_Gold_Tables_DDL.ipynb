# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.dim_cast(
cast_key BIGINT GENERATED ALWAYS AS IDENTITY,
cast_name string,
primary_profession string,
known_for_title string,
created_at timestamp,
updated_at timestamp
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.dim_category(
category_key BIGINT GENERATED ALWAYS AS IDENTITY,
category_name string,
category_type string,
created_at timestamp,
updated_at timestamp
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.dim_countries(
country_key BIGINT GENERATED ALWAYS AS IDENTITY,
country_name string,
continent string,
market_type string,
created_at timestamp,
updated_at timestamp
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.dim_directors(
director_key BIGINT GENERATED ALWAYS AS IDENTITY,
director_name string,
directing_style string,
active_years string,
created_at timestamp,
updated_at timestamp
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.dim_titles(
show_key BIGINT GENERATED ALWAYS AS IDENTITY,
title_name string,
duration_minutes int,
duration_seasons int,
type string,
date_added string,
release_year int,
rating string,
description string,
show_id string,
created_at timestamp,
updated_at timestamp
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.fact_title_snapshot(
show_key int,
snapshot_date string,
duration_minutes int,
duration_seasons int,
is_movie_flag string,
is_series_flag string,
is_new_release_flag string,
created_at timestamp,
updated_at timestamp
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.bridge_show_cast(
show_key int,
cast_key int
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.bridge_show_category(
show_key int,
category_key int
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.bridge_show_countries(
show_key int,
country_key int
)
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.gold.bridge_show_directors(
show_key int,
director_key int
)
USING DELTA;
