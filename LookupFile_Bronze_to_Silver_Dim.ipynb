# %%
files=[

    {
        'sourcefolder':'ott_cast'
    },
    {
        'sourcefolder':'ott_category'
    },
    {
        'sourcefolder':'ott_countries'
    },
    {
        'sourcefolder':'ott_directors'
    }
]

# %%
dbutils.jobs.taskValues.set(key='curr_arr',value=files)
