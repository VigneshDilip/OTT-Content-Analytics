# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.bronze.ott_cast
USING DELTA
LOCATION  'abfss://bronze@storageottanalytics.dfs.core.windows.net/ott_cast'

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.bronze.ott_category
USING DELTA
LOCATION  'abfss://bronze@storageottanalytics.dfs.core.windows.net/ott_category'

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.bronze.ott_countries
USING DELTA
LOCATION  'abfss://bronze@storageottanalytics.dfs.core.windows.net/ott_countries'

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.bronze.ott_directors
USING DELTA
LOCATION  'abfss://bronze@storageottanalytics.dfs.core.windows.net/ott_directors'

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.bronze.ott_titles
USING DELTA
LOCATION  'abfss://bronze@storageottanalytics.dfs.core.windows.net/ott_titles'

# %%
# %sql
CREATE TABLE IF NOT EXISTS ott_catalog.bronze.ott_title_snapshot
USING DELTA
LOCATION  'abfss://bronze@storageottanalytics.dfs.core.windows.net/ott_title_snapshot'
