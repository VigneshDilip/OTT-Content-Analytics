# %%
df=spark.read.format('csv').option('header','true').load('abfss://raw@storageottanalytics.dfs.core.windows.net/ott_title_snapshot')
df.display()

# %%
# %sql
select * from ott_catalog.bronze.ott_countries

# %%
# %sql
select count(*) from ott_catalog.silver.fact_title_snapshot

# %%
# %sql
drop table ott_catalog.silver.ott_category;
drop table ott_catalog.silver.ott_countries;
drop table ott_catalog.silver.ott_directors;
drop table ott_catalog.silver.ott_titles;
drop table ott_catalog.silver.event_log_a504a744_8acf_4e38_8ccf_9f2fe9705a5b;

# %%
# %sql
select * from ott_catalog.gold.fact_title_snapshot
